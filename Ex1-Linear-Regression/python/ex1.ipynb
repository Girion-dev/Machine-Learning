# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ex1data1.txt', delimiter = ",", header=None)

# %%
X = df.iloc[:, 0]
y = df.iloc[:, 1]
m = len(y)

# %%
plt.plot(X, y, 'rx')

# %%
df.insert(0, -1, 1) # Add a column of ones
theta = np.zeros(2)

# %%
# Cost Function and Gradient Descent

# Gradient descent settings
iterations = 1500
alpha = 0.01 # Learning rate

def costFunction(X, y, theta):
    m = len(y)
    X.T
    J = (1 / (2 * m)) * sum(np.square(np.subtract(X.dot(theta), y)))
    return J

J = costFunction(X, y, theta)
print("Cost: " + J)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-76-1bc67c7bcbae> in <module>
#      11     return J
#      12
# ---> 13 J = costFunction(X, y, theta)
#      14 print("Cost: " + J)
#
# <ipython-input-76-1bc67c7bcbae> in costFunction(X, y, theta)
#       8     m = len(y)
#       9     X.T
# ---> 10     J = (1 / (2 * m)) * sum(np.square(np.subtract(X.dot(theta), y)))
#      11     return J
#      12
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in dot(self, other)
#    2578             rvals = np.asarray(other)
#    2579             if lvals.shape[0] != rvals.shape[0]:
# -> 2580                 raise Exception(
#    2581                     f"Dot product shape mismatch, {lvals.shape} vs {rvals.shape}"
#    2582                 )
#
# Exception: Dot product shape mismatch, (97,) vs (2,)
