# %%
# Imports
import tensorflow_datasets as tfds

# %%
# Load dataset
wider_data = tfds.load("wider_face")
wider_train, wider_test = wider_data["train"], wider_data["test"]
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling wider_face-train.tfrecord...:   0%|          | 0/12880 [00:00<?, ? examples/s]
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling wider_face-validation.tfrecord...:   0%|          | 0/3226 [00:00<?, ? examples/s]
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling wider_face-test.tfrecord...:   0%|          | 0/16097 [00:00<?, ? examples/s]
# Dataset wider_face downloaded and prepared to /home/mateo/tensorflow_datasets/wider_face/0.1.0. Subsequent calls will reuse this data.

# %%
print(wider_train.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-56a3869634e0> in <module>
# ----> 1 print(wider_train.shape)
#
# AttributeError: 'PrefetchDataset' object has no attribute 'shape'
